# %%
a = 4
b = 10
c = 5.0
d = 1
f = 5

print(c != f)
# Out:
# False

# %%
not False
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
True or False and not True
# not > and > or
# Out:
# True
