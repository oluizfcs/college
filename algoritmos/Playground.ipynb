# %%
def recortarTexto():
  print("• Recortes de texto •")

  print("\nInsira o termo que devo verificar o número de ocorrências")
  termo = input("--> ")
  if not termo:
    print("O termo de pesquisa não pode ser vazio.")
    return

  print("\nAgora insira o texto em que o número de aparições do termo será contabilizado")
  texto = input("--> ")

  ocorrencias = texto.count(termo)

  if ocorrencias > 0:
    if ocorrencias == 1:
      print(f"\n O termo \"{termo}\" aparece apenas uma vez no texto: ")
    else:
      print(f"\n O termo \"{termo}\" aparece {ocorrencias} vezes no texto: ")

    while ocorrencias > 0:
      inicial = texto.find(termo)
      final = inicial + len(termo)

      # Evitar erros com o começo/final do texto
      inicio_exibicao = max(0, inicial - 3)
      fim_exibicao = min(len(texto), final + 3)

      print(texto[inicio_exibicao:fim_exibicao])

      # removendo a ocorrência atual do texto
      texto = texto[:inicial] + texto[final:]

      mudanca_de_txt = mudanca_de_txt[:comeco] + mudanca_de_txt[final:]

      print(f"\n\"{texto}\"\n")

      ocorrencias -= 1
  else:
    print(f"\n Procurei bastante, mas infelizmente o termo \"{termo}\" não aparece no texto nenhuma vez.")

recortarTexto()
# Out:
# • Recortes de texto •
#
# Insira o termo que devo verificar o número de ocorrências
# --> a
#
# Agora insira o texto em que o número de aparições do termo será contabilizado
# --> a dona aranha
#
#  O termo "a" aparece 5 vezes no texto:
# a do
#
# " dona aranha"
#
# dona ar
#
# " don aranha"
#
# on aran
#
# " don ranha"
#
# n ranha
#
# " don rnha"
#
# rnha
#
# " don rnh"

# %%
s = "abcdef"

s = s[:2] + s[4:]

s
# Out:
# 'abef'

# %%
len("palavra")
# Out:
# 7

# %%
"palavra".index("l")
# Out:
# 2

# %%
"palavra".find("l")
# Out:
# 2

# %%
mudanca_de_txt = "a dona aranha subiu pela parede"
mudanca_palavra = "a"

qtd_ocorrencias = mudanca_de_txt.count(mudanca_palavra)

while qtd_ocorrencias > 0:

  print(qtd_ocorrencias)

  qtd_ocorrencias -= 1
# Out:
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %%
max(0, 1, 3, 643)
# Out:
# 643

# %%
try:
  int(1.5)
except ValueError:
  print("Apenas números")
