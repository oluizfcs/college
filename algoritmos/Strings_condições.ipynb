# %%
frase = "Luiz Felipe"
frase_sem_espaco = frase.replace(" ", "")

imprimir = f"O nome \"{frase}\" tem {len(frase_sem_espaco)} letras."

print(imprimir)
# Out:
# O nome "Luiz Felipe" tem 10 letras.

# %%
string = "teste"

string[4]
# Out:
# 'e'

# %%
# concatenar
primeiro_nome = "Luiz Felipe"
sobrenome = " de Castro Santana"

nome = primeiro_nome + sobrenome

print(nome)
# Out:
# Luiz Felipe de Castro Santana

# %%
n = "20 \n" * 5

print(n)
# Out:
# 20
# 20
# 20
# 20
# 20

# %%
nome = "Luiz"
idade = 17.9998

print("%s tem %d anos." % (nome, idade))

print("{} tem {} anos.".format(nome, idade))

print(f"{nome} tem {idade:.0f} anos.")
# Out:
# Luiz tem 17 anos.
# Luiz tem 17.9998 anos.
# Luiz tem 18 anos.

# %%
id_produto = 0

for x in range(26):
  print(f"{id_produto:03} - Produto {x}")
  id_produto += 1
# Out:
# 000 - Produto 0
# 001 - Produto 1
# 002 - Produto 2
# 003 - Produto 3
# 004 - Produto 4
# 005 - Produto 5
# 006 - Produto 6
# 007 - Produto 7
# 008 - Produto 8
# 009 - Produto 9
# 010 - Produto 10
# 011 - Produto 11
# 012 - Produto 12
# 013 - Produto 13
# 014 - Produto 14
# 015 - Produto 15
# 016 - Produto 16
# 017 - Produto 17
# 018 - Produto 18
# 019 - Produto 19
# 020 - Produto 20
# 021 - Produto 21
# 022 - Produto 22
# 023 - Produto 23
# 024 - Produto 24
# 025 - Produto 25

# %%
a = '⨯'
b = 10

for x in range(10):
  print(a * x)
while b >= 0:
  print(a * b)
  b -= 1
# Out:
# ⨯
# ⨯⨯
# ⨯⨯⨯
# ⨯⨯⨯⨯
# ⨯⨯⨯⨯⨯
# ⨯⨯⨯⨯⨯⨯
# ⨯⨯⨯⨯⨯⨯⨯
# ⨯⨯⨯⨯⨯⨯⨯⨯
# ⨯⨯⨯⨯⨯⨯⨯⨯⨯
# ⨯⨯⨯⨯⨯⨯⨯⨯⨯⨯
# ⨯⨯⨯⨯⨯⨯⨯⨯⨯
# ⨯⨯⨯⨯⨯⨯⨯⨯
# ⨯⨯⨯⨯⨯⨯⨯
# ⨯⨯⨯⨯⨯⨯
# ⨯⨯⨯⨯⨯
# ⨯⨯⨯⨯
# ⨯⨯⨯
# ⨯⨯
# ⨯

# %%
a = "Luiz"

print(a[-1])
# Out:
# z

# %%
# Cálculo do Imposto de Renda

salario = float(input("Insira o salário: "))
ir = 0
ir1 = 0
ir2 = 0

if salario <= 1000:

  print("Isento")

if salario > 1000:

  restante = salario - 1000
  ir1 = restante * 0.2
  print(f"20% IR = R$:{ir1:,.2f}")

if restante > 3000:

  restante -= 3000
  ir2 = restante * 0.35
  print(f"35% IR = R$:{ir2:,.2f}")

ir = ir1 + ir2
print(f"Imposto de Renda = R$:{ir:,.2f}")
# Out:
# Insira o salário: 5000
# 20% IR = R$:800.00
# 35% IR = R$:350.00
# Imposto de Renda = R$:1,150.00

# %%
salario = float(input("Digite o salário: "))
base = salario
imposto = 0

if base > 3000:
  imposto = imposto + ((base - 3000) * 0.35)
  base = 3000
if base > 1000:
  imposto = imposto + ((base - 1000) * 0.2)

print(f"Salário: R${salario:6.2f} - Imposto a pagar: R${imposto:6.2f}")
# Out:
# Digite o salário: 5000
# Salário: R$5000.00 - Imposto a pagar: R$1100.00

# %%
minutos = int(input("Insira os minutos: "))

if minutos < 200:
  preco = 0.2
elif minutos < 400:
  preco = 0.18
else:
  preco = 0.15

print(f"Conta = R$:{minutos * preco:,.2f}")
# Out:
# Insira os minutos: 500
# Conta = R$:75.00

# %%
A = float(input())
B = float(input())

A *= 3.5
B *= 7.5

MEDIA = (A + B) / 11

print(f"MEDIA = {MEDIA:.5f}")
# Out:
# 10.0
# 10.0
# MEDIA = 10.00000
